# %%
import torch

print(torch.cuda.get_device_name(0))
free, total = torch.cuda.mem_get_info()
print(f"GPU memory: {free/1e9:.2f} GB free / {total/1e9:.2f} GB total")
# Out:
# NVIDIA GeForce RTX 3060
# GPU memory: 12.50 GB free / 12.62 GB total
