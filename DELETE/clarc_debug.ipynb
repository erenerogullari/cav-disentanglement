# %%
import torch
import pickle
import pandas as pd
from pathlib import Path

# %%
with open("/home/erogullari/Workspace/cav-disentanglement/results/model_correction/vgg16/features.28/pattern_cav/alpha0.1_lr0.001/metrics/all_metrics.pkl", "rb") as f:
    all_metrics = pickle.load(f)
with open("/home/erogullari/Workspace/cav-disentanglement/results/model_correction/vgg16/features.28/pattern_cav/alpha0.1_lr0.001/metrics/accuracy_metrics.pkl", "rb") as f:
    accuracy_metrics = pickle.load(f)


df = pd.DataFrame(all_metrics)
start = 20
df[start:start+20]
# Out:
#                               Metric     Value         Model
# 20  test_acc_Non-Blond_Hair_attacked  0.772261       Vanilla
# 21      test_acc_Blond_Hair_attacked  0.772261       Vanilla
# 22               test_accuracy_clean  0.952369       Vanilla
# 23  test_accuracy_standard_err_clean  0.001496       Vanilla
# 24                     test_f1_clean  0.906644       Vanilla
# 25     test_AUC_Non-Blond_Hair_clean  0.981652       Vanilla
# 26         test_AUC_Blond_Hair_clean  0.981569       Vanilla
# 27     test_fpr_Non-Blond_Hair_clean  0.150448       Vanilla
# 28         test_fpr_Blond_Hair_clean  0.029683       Vanilla
# 29     test_fnr_Non-Blond_Hair_clean  0.029683       Vanilla
# 30         test_fnr_Blond_Hair_clean  0.150448       Vanilla
# 31     test_acc_Non-Blond_Hair_clean  0.952369       Vanilla
# 32         test_acc_Blond_Hair_clean  0.952369       Vanilla
# 33                  test_accuracy_ch  0.906120  Baseline CAV
# 34     test_accuracy_standard_err_ch  0.002049  Baseline CAV
# 35                        test_f1_ch  0.762080  Baseline CAV
# 36        test_AUC_Non-Blond_Hair_ch  0.898096  Baseline CAV
# 37            test_AUC_Blond_Hair_ch  0.899449  Baseline CAV
# 38        test_fpr_Non-Blond_Hair_ch  0.569246  Baseline CAV
# 39            test_fpr_Blond_Hair_ch  0.010899  Baseline CAV

# %%
with open("/home/erogullari/Workspace/cav-disentanglement/results/model_correction/vgg16/features.28/pattern_cav/alpha0.01_lr0.001_opt/metrics/selected_metrics.pkl", "rb") as f:
    selected_metrics = pickle.load(f)
selected_metrics.keys()
df_selected = pd.DataFrame(selected_metrics)

# %%
df_selected
# Out:
#                     Metric     Value           Model  Category    Metric Type
# 11  test_accuracy_attacked  0.774951         Vanilla  attacked  test_accuracy
# 16     test_fpr_0_attacked  0.038922         Vanilla  attacked     test_fpr_0
# 17     test_fpr_1_attacked  0.261404         Vanilla  attacked       test_fpr
# 18     test_fnr_0_attacked  0.261404         Vanilla  attacked     test_fnr_0
# 19     test_fnr_1_attacked  0.038922         Vanilla  attacked       test_fnr
# 22     test_accuracy_clean  0.964286         Vanilla     clean  test_accuracy
# 27        test_fpr_0_clean  0.116766         Vanilla     clean     test_fpr_0
# 28        test_fpr_1_clean  0.019883         Vanilla     clean       test_fpr
# 29        test_fnr_0_clean  0.019883         Vanilla     clean     test_fnr_0
# 30        test_fnr_1_clean  0.116766         Vanilla     clean       test_fnr
# 44  test_accuracy_attacked  0.852250    Baseline CAV  attacked  test_accuracy
# 49     test_fpr_0_attacked  0.904192    Baseline CAV  attacked     test_fpr_0
# 50     test_fpr_1_attacked  0.000000    Baseline CAV  attacked       test_fpr
# 51     test_fnr_0_attacked  0.000000    Baseline CAV  attacked     test_fnr_0
# 52     test_fnr_1_attacked  0.904192    Baseline CAV  attacked       test_fnr
# 55     test_accuracy_clean  0.942270    Baseline CAV     clean  test_accuracy
# 60        test_fpr_0_clean  0.317365    Baseline CAV     clean     test_fpr_0
# 61        test_fpr_1_clean  0.007018    Baseline CAV     clean       test_fpr
# 62        test_fnr_0_clean  0.007018    Baseline CAV     clean     test_fnr_0
# 63        test_fnr_1_clean  0.317365    Baseline CAV     clean       test_fnr
# 77  test_accuracy_attacked  0.885029  Orthogonal CAV  attacked  test_accuracy
# 82     test_fpr_0_attacked  0.041916  Orthogonal CAV  attacked     test_fpr_0
# 83     test_fpr_1_attacked  0.129240  Orthogonal CAV  attacked       test_fpr
# 84     test_fnr_0_attacked  0.129240  Orthogonal CAV  attacked     test_fnr_0
# 85     test_fnr_1_attacked  0.041916  Orthogonal CAV  attacked       test_fnr
# 88     test_accuracy_clean  0.962329  Orthogonal CAV     clean  test_accuracy
# 93        test_fpr_0_clean  0.119760  Orthogonal CAV     clean     test_fpr_0
# 94        test_fpr_1_clean  0.021637  Orthogonal CAV     clean       test_fpr
# 95        test_fnr_0_clean  0.021637  Orthogonal CAV     clean     test_fnr_0
# 96        test_fnr_1_clean  0.119760  Orthogonal CAV     clean       test_fnr
